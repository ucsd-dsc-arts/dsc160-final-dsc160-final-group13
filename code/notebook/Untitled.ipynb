# %%
import pandas as pd
import numpy as np
import math
from miditime.miditime import MIDITime

# %%
time = pd.read_csv("data/time_series_data.csv")
others=pd.read_csv("data/other_information.csv")
location=pd.read_csv("data/location.csv")

# %%
time
# Out:
#                       Combined_Key  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0                         Guam, US        0        0        0        0
# 1     Northern Mariana Islands, US        0        0        0        0
# 2                  Puerto Rico, US        0        0        0        0
# 3               Virgin Islands, US        0        0        0        0
# 4             Autauga, Alabama, US        0        0        0        0
# ...                            ...      ...      ...      ...      ...
# 3035        Central Utah, Utah, US        0        0        0        0
# 3036      Southeast Utah, Utah, US        0        0        0        0
# 3037      Southwest Utah, Utah, US        0        0        0        0
# 3038           TriCounty, Utah, US        0        0        0        0
# 3039        Weber-Morgan, Utah, US        0        0        0        0
#
#       1/26/20  1/27/20  1/28/20  1/29/20  1/30/20  ...  5/26/20  5/27/20  \
# 0           0        0        0        0        0  ...      167      170
# 1           0        0        0        0        0  ...       22       22
# 2           0        0        0        0        0  ...     3324     3397
# 3           0        0        0        0        0  ...       69       69
# 4           0        0        0        0        0  ...      189      192
# ...       ...      ...      ...      ...      ...  ...      ...      ...
# 3035        0        0        0        0        0  ...       33       33
# 3036        0        0        0        0        0  ...       21       23
# 3037        0        0        0        0        0  ...      330      335
# 3038        0        0        0        0        0  ...       20       20
# 3039        0        0        0        0        0  ...      272      273
#
#       5/28/20  5/29/20  5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  6/4/20
# 0         171      172      172      172     175     175     177     179
# 1          22       22       22       22      22      23      24      26
# 2        3486     3647     3718     3776    3873    3935    4023    4508
# 3          69       69       69       69      70      70      70      71
# 4         205      212      216      221     233     239     239     241
# ...       ...      ...      ...      ...     ...     ...     ...     ...
# 3035       34       38       38       38      38      38      39      39
# 3036       23       23       24       24      24      26      26      26
# 3037      360      386      423      440     454     476     498     524
# 3038       20       18       20       21      21      20      20      20
# 3039      276      288      293      298     303     308     316     330
#
# [3040 rows x 136 columns]

# %%
workingWith=time.T

# %%
new_header=workingWith.iloc[0]
workingWith=workingWith[1:]
workingWith.columns=new_header

# %%
dailyGrowthMax=workingWith.diff(axis=0).max(axis=1)

# %%
maxofUSCaseGrowth=dailyGrowthMax.max(skipna=True)

# %%
central=workingWith.diff(axis=0)

# %%
central=central.iloc[1:,:]
central
# Out:
# Combined_Key Guam, US Northern Mariana Islands, US Puerto Rico, US  \
# 1/24/20             0                            0               0
# 1/25/20             0                            0               0
# 1/26/20             0                            0               0
# 1/27/20             0                            0               0
# 1/28/20             0                            0               0
# ...               ...                          ...             ...
# 5/31/20             0                            0              58
# 6/1/20              3                            0              97
# 6/2/20              0                            1              62
# 6/3/20              2                            1              88
# 6/4/20              2                            2             485
#
# Combined_Key Virgin Islands, US Autauga, Alabama, US Baldwin, Alabama, US  \
# 1/24/20                       0                    0                    0
# 1/25/20                       0                    0                    0
# 1/26/20                       0                    0                    0
# 1/27/20                       0                    0                    0
# 1/28/20                       0                    0                    0
# ...                         ...                  ...                  ...
# 5/31/20                       0                    5                    7
# 6/1/20                        1                   12                    2
# 6/2/20                        0                    6                    0
# 6/3/20                        0                    0                    0
# 6/4/20                        1                    2                    1
#
# Combined_Key Barbour, Alabama, US Bibb, Alabama, US Blount, Alabama, US  \
# 1/24/20                         0                 0                   0
# 1/25/20                         0                 0                   0
# 1/26/20                         0                 0                   0
# 1/27/20                         0                 0                   0
# 1/28/20                         0                 0                   0
# ...                           ...               ...                 ...
# 5/31/20                        17                 3                   1
# 6/1/20                          5                 1                   1
# 6/2/20                          3                 0                   0
# 6/3/20                          2                 0                   0
# 6/4/20                          0                 0                   0
#
# Combined_Key Bullock, Alabama, US  ... Dukes and Nantucket,Massachusetts,US  \
# 1/24/20                         0  ...                                    0
# 1/25/20                         0  ...                                    0
# 1/26/20                         0  ...                                    0
# 1/27/20                         0  ...                                    0
# 1/28/20                         0  ...                                    0
# ...                           ...  ...                                  ...
# 5/31/20                         6  ...                                    1
# 6/1/20                          0  ...                                   13
# 6/2/20                          4  ...                                    1
# 6/3/20                          2  ...                                    0
# 6/4/20                          2  ...                                    1
#
# Combined_Key Kansas City,Missouri,US  \
# 1/24/20                            0
# 1/25/20                            0
# 1/26/20                            0
# 1/27/20                            0
# 1/28/20                            0
# ...                              ...
# 5/31/20                           33
# 6/1/20                            37
# 6/2/20                            96
# 6/3/20                            51
# 6/4/20                            71
#
# Combined_Key Michigan Department of Corrections (MDOC), Michigan, US  \
# 1/24/20                                                       0
# 1/25/20                                                       0
# 1/26/20                                                       0
# 1/27/20                                                       0
# 1/28/20                                                       0
# ...                                                         ...
# 5/31/20                                                      19
# 6/1/20                                                        0
# 6/2/20                                                       32
# 6/3/20                                                        5
# 6/4/20                                                       17
#
# Combined_Key Federal Correctional Institution (FCI), Michigan, US  \
# 1/24/20                                                       0
# 1/25/20                                                       0
# 1/26/20                                                       0
# 1/27/20                                                       0
# 1/28/20                                                       0
# ...                                                         ...
# 5/31/20                                                       0
# 6/1/20                                                        0
# 6/2/20                                                        1
# 6/3/20                                                        2
# 6/4/20                                                        3
#
# Combined_Key Bear River, Utah, US Central Utah, Utah, US  \
# 1/24/20                         0                      0
# 1/25/20                         0                      0
# 1/26/20                         0                      0
# 1/27/20                         0                      0
# 1/28/20                         0                      0
# ...                           ...                    ...
# 5/31/20                        28                      0
# 6/1/20                         28                      0
# 6/2/20                         21                      0
# 6/3/20                         38                      1
# 6/4/20                         28                      0
#
# Combined_Key Southeast Utah, Utah, US Southwest Utah, Utah, US  \
# 1/24/20                             0                        0
# 1/25/20                             0                        0
# 1/26/20                             0                        0
# 1/27/20                             0                        0
# 1/28/20                             0                        0
# ...                               ...                      ...
# 5/31/20                             0                       17
# 6/1/20                              0                       14
# 6/2/20                              2                       22
# 6/3/20                              0                       22
# 6/4/20                              0                       26
#
# Combined_Key TriCounty, Utah, US Weber-Morgan, Utah, US
# 1/24/20                        0                      0
# 1/25/20                        0                      0
# 1/26/20                        0                      0
# 1/27/20                        0                      0
# 1/28/20                        0                      0
# ...                          ...                    ...
# 5/31/20                        1                      5
# 6/1/20                         0                      5
# 6/2/20                        -1                      5
# 6/3/20                         0                      8
# 6/4/20                         0                     14
#
# [133 rows x 3040 columns]

# %%
for index,row in central.iterrows():
    for element in row:
# Out:
#   File "<ipython-input-26-a73f247c8699>", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
testInput = central.iloc[120,:]
testInput.values
# Out:
# array([0, 0, 70, ..., 13, -1, 4], dtype=object)

# %%
mymidi = MIDITime(120, 'myfile.mid', base_octave=2, octave_range = 1)
noteList = []
c_major = ['C', 'D', 'E', 'F', 'G', 'A', 'B']

for element in testInput:
    if element > 0:
        noteList.append(mymidi.log_scale_pct(1, maxofUSCaseGrowth, central.iloc[120,-3], direction="log"))


# for d in testInput:
#     print(d)

# def setMidi(row):
#     thisMidi=[]
#     for element in row:
#         thisMidi.append(MIDITime(outfile="test.mid", ))

# %%
pd.Series(noteList).describe()
# Out:
# count    1.424000e+03
# mean     2.860556e-01
# std      5.553065e-17
# min      2.860556e-01
# 25%      2.860556e-01
# 50%      2.860556e-01
# 75%      2.860556e-01
# max      2.860556e-01
# dtype: float64
